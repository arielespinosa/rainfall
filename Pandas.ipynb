# %%
import numpy as np
import pandas as pd

# %%
stations = pd.read_csv("outputs/observaciones.csv", sep=',')
stations.dtypes
# Out:
# Estacion      int64
# Ano           int64
# Mes           int64
# Dia           int64
# Hora          int64
# RR          float64
# dtype: object

# %%
stations[(stations['Estacion'] == 78310) & (stations['RR'].notna())]
# Out:
#       Estacion   Ano  Mes  Dia  Hora    RR
# 0        78310  2017    1    1     1   0.0
# 1        78310  2017    1    1     2   0.0
# 2        78310  2017    1    1     3   0.0
# 3        78310  2017    1    1     4   0.0
# 4        78310  2017    1    1     5   0.0
# 5        78310  2017    1    1     6   0.0
# 6        78310  2017    1    1     7   0.0
# 7        78310  2017    1    1     8   0.0
# 8        78310  2017    1    2     1   0.0
# 9        78310  2017    1    2     2   0.0
# 10       78310  2017    1    2     3   0.0
# 11       78310  2017    1    2     4   0.0
# 12       78310  2017    1    2     5   0.0
# 13       78310  2017    1    2     6   0.0
# 14       78310  2017    1    2     7   0.0
# 15       78310  2017    1    2     8   0.0
# 16       78310  2017    1    3     1  43.8
# 17       78310  2017    1    3     2   2.0
# 18       78310  2017    1    3     3   0.1
# 19       78310  2017    1    3     4   0.0
# 20       78310  2017    1    3     5   0.0
# ...

# %%
data = stations[(stations['Estacion'] == 78310) & (stations['RR'].notna())].to_numpy()[:, 1:]
data
# Out:
# array([[2.017e+03, 1.000e+00, 1.000e+00, 1.000e+00, 0.000e+00],
#        [2.017e+03, 1.000e+00, 1.000e+00, 2.000e+00, 0.000e+00],
#        [2.017e+03, 1.000e+00, 1.000e+00, 3.000e+00, 0.000e+00],
#        ...,
#        [2.017e+03, 1.200e+01, 3.100e+01, 6.000e+00, 0.000e+00],
#        [2.017e+03, 1.200e+01, 3.100e+01, 7.000e+00, 0.000e+00],
#        [2.017e+03, 1.200e+01, 3.100e+01, 8.000e+00, 0.000e+00]])

# %%
stations.Estacion.unique()
# Out:
# array([78310, 78312, 78313, 78314, 78315, 78316, 78317, 78318, 78320,
#        78376, 78322, 78323, 78340, 78374, 78375, 78325, 78373, 78327,
#        78328, 78329, 78330, 78331, 78332, 78333, 78335, 78344, 78308,
#        78326, 78338, 78343, 78348, 78337, 78341, 78342, 78349, 78339,
#        78345, 78346, 78347, 78350, 78351, 78352, 78353, 78354, 78355,
#        78357, 78358, 78362, 78365, 78370, 78372, 78378, 78359, 78360,
#        78361, 78377, 78363, 78364, 78366, 78319, 78334, 78356, 78368,
#        78369, 78309, 78321, 78324])

# %%
from files.observations import *

# %%
obs = Observations("outputs/observaciones.csv")
obs.StationsId()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-130-4d87c5eb509d> in <module>
#       1 obs = Observations("outputs/observaciones.csv")
# ----> 2 obs.StationsId()
#
# AttributeError: 'Observations' object has no attribute 'StationsId'

# %%
obs.GetStationObservation(78310)
#obs.stations[(obs.stations['Estacion'] == 78310) & (obs.stations['RR'].notna())].to_numpy()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-131-f7f75285a04e> in <module>
# ----> 1 obs.GetStationObservation(78310)
#       2 #obs.stations[(obs.stations['Estacion'] == 78310) & (obs.stations['RR'].notna())].to_numpy()
#
# ~/Ariel/rain/proyecto/files/observations.py in GetStationObservation(self, station_id, nan_values, utc)
#      76         return stations.Estacion.unique()
#      77
# ---> 78     # Get all observation from a station where rainfall is not emtpy
#      79     def GetStationObservation(self, station_id, nan_values=False, utc=True):
#      80         stations = self.Read()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
obs.Esta()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-128-2d5675eadefc> in <module>
# ----> 1 obs.Esta()
#
# AttributeError: 'Observations' object has no attribute 'Esta'
